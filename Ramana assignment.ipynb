# %%
import pandas as pd
import numpy as npb

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
companies = pd.read_excel("dataset.xlsx",sheetname="Companies",header=0,index_col=False,keep_default_na=True)

# %%
companies.head()
# Out:
#                          permalink                name  \
# 0            /organization/waywire            #waywire
# 1  /organization/tv-communications  &TV Communications
# 2    /organization/rock-your-paper   'Rock' Your Paper
# 3   /organization/in-touch-network   (In)Touch Network
# 4   /organization/r-ranch-and-mine  -R- Ranch and Mine
#
#                     homepage_url  \
# 0         http://www.waywire.com
# 1          http://enjoyandtv.com
# 2   http://www.rockyourpaper.org
# 3  http://www.InTouchNetwork.com
# 4                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
# ...

# %%
rounds = pd.read_excel("dataset.xlsx",sheetname="Rounds",header=0,index_col=False,keep_default_na=True)
investments = pd.read_excel("dataset.xlsx",sheetname="Investments",header=0,index_col=False,keep_default_na=True)
acquisitions = pd.read_excel("dataset.xlsx",sheetname="Acquisitions",header=0,index_col=False,keep_default_na=True)
additions = pd.read_excel("dataset.xlsx",sheetname="Additions",header=0,index_col=False,keep_default_na=True)

# %%
rounds.head()
# Out:
#                  company_permalink        company_name  \
# 0            /organization/waywire            #waywire
# 1  /organization/tv-communications  &TV Communications
# 2  /organization/tv-communications  &TV Communications
# 3    /organization/rock-your-paper   'Rock' Your Paper
# 4   /organization/in-touch-network   (In)Touch Network
#
#                                company_category_list company_market  \
# 0         |Entertainment|Politics|Social Media|News|           News
# 1                                            |Games|          Games
# 2                                            |Games|          Games
# 3                             |Publishing|Education|     Publishing
# 4  |Electronics|Guides|Coffee|Restaurants|Music|i...    Electronics
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  USA                 CA    Los Angeles  Los Angeles
# ...

# %%
investments.head()
# Out:
#                      company_permalink           company_name  \
# 0         /organization/test-company-3           test company
# 1  /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 2               /organization/abo-data               ABO Data
# 3               /organization/abo-data               ABO Data
# 4                   /organization/ikro                   Ikro
#
#                                company_category_list       company_market  \
# 0                                                NaN                  NaN
# 1  |Internet|SEO|Services|Public Relations|Social...             Internet
# 2                              |Enterprise Software|  Enterprise Software
# 3                              |Enterprise Software|  Enterprise Software
# 4                                                NaN                  NaN
#
#   company_country_code company_state_code company_region company_city  \
# 0                  ARE                NaN          Dubai        Dubai
# ...

# %%
acquisitions.head()
# Out:
#                  company_permalink    company_name  \
# 0            /organization/waywire        #waywire
# 1      /organization/fluff-friends  (fluff)Friends
# 2                /organization/red           (RED)
# 3  /organization/vandaele-holdings               .
# 4        /organization/co-internet             .CO
#
#                         company_category_list company_market  \
# 0  |Entertainment|Politics|Social Media|News|           News
# 1                                         NaN            NaN
# 2                                |Nonprofits|     Nonprofits
# 3                                         NaN            NaN
# 4            |Registrars|Domains|Curated Web|     Registrars
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  NaN                NaN            NaN          NaN
# 2                  USA                 NY  New York City     New York
# ...

# %%
additions.head()
# Out:
#                    content month_str quarter_str  year_str  value
# 0  Profiles: Organizations   2007-05     2007-Q2      2007     14
# 1  Profiles: Organizations   2007-06     2007-Q2      2007     96
# 2  Profiles: Organizations   2007-07     2007-Q3      2007    259
# 3  Profiles: Organizations   2007-08     2007-Q3      2007    522
# 4  Profiles: Organizations   2007-09     2007-Q3      2007    219

# %%
investments.sort_values(['company_permalink', 'funded_month'], inplace=True)

# %%
investments.head()
# Out:
#                        company_permalink        company_name  \
# 21692              /organization/0-6-com             0-6.com
# 107638    /organization/004-technologies    004 Technologies
# 106041  /organization/01games-technology  01Games Technology
# 74152               /organization/0xdata              H2O.ai
# 107283              /organization/0xdata              H2O.ai
#
#        company_category_list company_market company_country_code  \
# 21692          |Curated Web|    Curated Web                  NaN
# 107638            |Software|       Software                  USA
# 106041               |Games|          Games                  HKG
# 74152            |Analytics|      Analytics                  USA
# 107283           |Analytics|      Analytics                  USA
#
#        company_state_code         company_region   company_city  \
# 21692                 NaN                    NaN            NaN
# 107638                 IL  Springfield, Illinois      Champaign
# ...

# %%
# Investment round summary
grouped_investments = investments.groupby('funding_round_type')
with pd.option_context('display.max_columns', 40):
    print(grouped_investments['raised_amount_usd'].describe(include='all'))
# Out:
# funding_round_type
# angel                count    3.998000e+03
#                      mean     1.106030e+06
#                      std      2.364456e+06
#                      min      0.000000e+00
#                      25%               NaN
#                      50%               NaN
#                      75%               NaN
#                      max      6.359026e+07
# convertible_note     count    4.460000e+02
#                      mean     1.067083e+06
#                      std      1.036196e+06
#                      min      1.295500e+04
#                      25%               NaN
#                      50%               NaN
#                      75%               NaN
#                      max      1.000000e+07
# debt_financing       count    1.462000e+03
#                      mean     2.148835e+07
#                      std      5.878093e+07
#                      min      1.300000e+04
#                      25%               NaN
# ...

# %%
investments.
